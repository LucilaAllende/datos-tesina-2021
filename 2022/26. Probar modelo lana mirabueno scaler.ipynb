# %%
from statsmodels.iolib.smpickle import load_pickle
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score, mean_squared_error

import matplotlib.pyplot as plt
import seaborn as sns

# %%
modelo_lana = load_pickle('modelo_prediccion_lana_3')

# %% [markdown]
# ## Prueba con dataset MIrabueno

# %%
data = pd.read_csv("datos_producidos/datos_dptp_ha.csv")
data
# Out:
#           fecha  hectareas departamento  carneros  ovejas  borregos  capones  \
# 0    2012-12-31    1294000       BIEDMA      5785   93378     30168    48447
# 1    2013-12-31    1294000       BIEDMA      5376   82998     25341    47350
# 2    2014-12-31    1294000       BIEDMA      4785   82706     29379    35155
# 3    2015-12-31    1294000       BIEDMA      4440   89262     29663    35437
# 4    2016-12-31    1294000       BIEDMA      4452   82295     33662    33470
# ..          ...        ...          ...       ...     ...       ...      ...
# 196  2016-12-31    1989300       TELSEN      4896   80262     26471    39243
# 197  2017-12-31    1989300       TELSEN      4640   77556     27296    36570
# 198  2018-12-31    1989300       TELSEN      4832   79117     28366    37558
# 199  2019-12-31    1989300       TELSEN      4781   80109     28428    38109
# 200  2020-12-31    1989300       TELSEN      2870   79157     25804    36901
#
#      cordero/as  total_ovinos  kilos_lana  finura  rinde  humedad  \
# 0         16071        193849    649130.0   19.80  58.06    58.40
# 1         26832        187897    620176.0   19.60  56.68    64.70
# 2         29900        181925    649130.0   20.10  61.19    60.50
# 3         32343        191145    672480.0   18.58  58.18    58.70
# 4         21326        175205    653800.0   17.99  59.93    57.50
# ..          ...           ...         ...     ...    ...      ...
# 196       20290        171162    637000.0   20.20  53.55    50.80
# 197       17750        163812    637000.0   19.11  56.01    47.17
# 198       21933        171806    637000.0   20.38  54.64    47.93
# 199       17731        169158    613021.5   16.88  53.83    47.57
# 200       18984        163716    614250.0   21.55  52.96    46.63
#
#      cant_lluvia  tem_max  temp_media  temp_min
# 0          46.40    18.10       12.40      6.70
# 1         226.50    19.90       14.20      8.80
# 2         331.30    20.60       14.70      9.20
# 3         114.20    22.20       15.80     10.20
# 4          88.90    25.20       18.60     12.90
# ..           ...      ...         ...       ...
# 196       273.33    17.47       11.57      5.77
# 197       220.03    16.60       10.93      5.03
# 198       201.40    17.63       11.33      5.03
# 199       119.47    17.53       11.17      4.83
# 200       101.47    16.60       10.60      4.60
#
# [201 rows x 17 columns]

# %%
def transform_data(data_array):
    return [item for lista in data_array.tolist() for item in lista]

# %%
def scaler_data(attr):     
    standard_scaler = StandardScaler()
    x_values = data[attr]
    standard_scaler.fit(x_values)
    return standard_scaler.transform(x_values)

# %%
ha = transform_data(scaler_data(['hectareas']))
data.insert(2, "ha_s", ha, allow_duplicates=False)

ovinos = transform_data(scaler_data(['total_ovinos']))
data.insert(10, "ovinos_s", ovinos, allow_duplicates=False)

lana = transform_data(scaler_data(['kilos_lana']))
data.insert(12, "kg_lana_s", lana, allow_duplicates=False)

lluvia = transform_data(scaler_data(['cant_lluvia']))
data.insert(17, "lluvia_s", lluvia, allow_duplicates=False)

data
# Out:
#           fecha  hectareas      ha_s departamento  carneros  ovejas  borregos  \
# 0    2012-12-31    1294000  0.143866       BIEDMA      5785   93378     30168
# 1    2013-12-31    1294000  0.143866       BIEDMA      5376   82998     25341
# 2    2014-12-31    1294000  0.143866       BIEDMA      4785   82706     29379
# 3    2015-12-31    1294000  0.143866       BIEDMA      4440   89262     29663
# 4    2016-12-31    1294000  0.143866       BIEDMA      4452   82295     33662
# ..          ...        ...       ...          ...       ...     ...       ...
# 196  2016-12-31    1989300  1.066650       TELSEN      4896   80262     26471
# 197  2017-12-31    1989300  1.066650       TELSEN      4640   77556     27296
# 198  2018-12-31    1989300  1.066650       TELSEN      4832   79117     28366
# 199  2019-12-31    1989300  1.066650       TELSEN      4781   80109     28428
# 200  2020-12-31    1989300  1.066650       TELSEN      2870   79157     25804
#
#      capones  cordero/as  total_ovinos  ...  kilos_lana  kg_lana_s  finura  \
# 0      48447       16071        193849  ...    649130.0  -0.301153   19.80
# 1      47350       26832        187897  ...    620176.0  -0.336719   19.60
# 2      35155       29900        181925  ...    649130.0  -0.301153   20.10
# 3      35437       32343        191145  ...    672480.0  -0.272472   18.58
# 4      33470       21326        175205  ...    653800.0  -0.295417   17.99
# ..       ...         ...           ...  ...         ...        ...     ...
# 196    39243       20290        171162  ...    637000.0  -0.316053   20.20
# 197    36570       17750        163812  ...    637000.0  -0.316053   19.11
# 198    37558       21933        171806  ...    637000.0  -0.316053   20.38
# 199    38109       17731        169158  ...    613021.5  -0.345507   16.88
# 200    36901       18984        163716  ...    614250.0  -0.343998   21.55
#
#      rinde  humedad  cant_lluvia  lluvia_s  tem_max  temp_media  temp_min
# 0    58.06    58.40        46.40 -0.953366    18.10       12.40      6.70
# 1    56.68    64.70       226.50  0.109007    19.90       14.20      8.80
# 2    61.19    60.50       331.30  0.727202    20.60       14.70      9.20
# 3    58.18    58.70       114.20 -0.553428    22.20       15.80     10.20
# 4    59.93    57.50        88.90 -0.702667    25.20       18.60     12.90
# ..     ...      ...          ...       ...      ...         ...       ...
# 196  53.55    50.80       273.33  0.385248    17.47       11.57      5.77
# 197  56.01    47.17       220.03  0.070842    16.60       10.93      5.03
# 198  54.64    47.93       201.40 -0.039052    17.63       11.33      5.03
# 199  53.83    47.57       119.47 -0.522341    17.53       11.17      4.83
# 200  52.96    46.63       101.47 -0.628519    16.60       10.60      4.60
#
# [201 rows x 21 columns]

# %%
data_mirabueno = data[data.departamento=='MIRABUENO']
data_mirabueno
# Out:
#           fecha  hectareas      ha_s departamento  carneros  ovejas  borregos  \
# 74   1985-12-31        250 -1.573166    MIRABUENO        50    1419       563
# 75   1986-12-31        250 -1.573166    MIRABUENO        53    1520       605
# 76   1987-12-31        250 -1.573166    MIRABUENO        67    1928       637
# 77   1988-12-31        250 -1.573166    MIRABUENO        55    1560       575
# 78   1989-12-31        250 -1.573166    MIRABUENO        42    1210       457
# 79   1990-12-31        250 -1.573166    MIRABUENO        35     998       390
# 80   1991-12-31        250 -1.573166    MIRABUENO        39    1122       407
# 81   1992-12-31        250 -1.573166    MIRABUENO        39    1125       451
# 82   1993-12-31        250 -1.573166    MIRABUENO        43    1240       447
# 83   1994-12-31        250 -1.573166    MIRABUENO        32     925       428
# 84   1995-12-31        250 -1.573166    MIRABUENO        41    1159       361
# 85   1996-12-31        250 -1.573166    MIRABUENO        30     849       354
# 86   1997-12-31        250 -1.573166    MIRABUENO        27     768       319
# 87   1998-12-31        250 -1.573166    MIRABUENO        39    1124       453
# 88   1999-12-31        250 -1.573166    MIRABUENO        39    1124       484
# 89   2000-12-31        250 -1.573166    MIRABUENO        57    1632       515
# 90   2001-12-31        250 -1.573166    MIRABUENO        48    1378       544
# 91   2002-12-31        250 -1.573166    MIRABUENO        59    1688       561
# 92   2003-12-31        250 -1.573166    MIRABUENO        68    1952       615
# 93   2004-12-31        250 -1.573166    MIRABUENO        65    1860       580
# 94   2005-12-31        250 -1.573166    MIRABUENO       108    3083       763
# 95   2006-12-31        250 -1.573166    MIRABUENO        65    1850       582
# 96   2007-12-31        250 -1.573166    MIRABUENO        64    1842       506
# 97   2008-12-31        250 -1.573166    MIRABUENO        43    1232       351
# 98   2009-12-31        250 -1.573166    MIRABUENO        39    1101       318
# 99   2010-12-31        250 -1.573166    MIRABUENO        35    1009       363
# 100  2011-12-31        250 -1.573166    MIRABUENO        34     970       275
# 101  2012-12-31        250 -1.573166    MIRABUENO        31     896       283
# 102  2013-12-31        250 -1.573166    MIRABUENO        32     923       325
# 103  2014-12-31        250 -1.573166    MIRABUENO        63    1800       451
# 104  2015-12-31        250 -1.573166    MIRABUENO        75    2130       654
# 105  2016-12-31        250 -1.573166    MIRABUENO        81    2311       683
# 106  2017-12-31        250 -1.573166    MIRABUENO        71    2032       701
# 107  2018-12-31        250 -1.573166    MIRABUENO        42    1200       478
# 108  2019-12-31        250 -1.573166    MIRABUENO       103    2940       806
# 109  2020-12-31        250 -1.573166    MIRABUENO        71    2021       533
#
#      capones  cordero/as  total_ovinos  ...  kilos_lana  kg_lana_s  finura  \
# 74       690         912          3634  ...     15600.0  -1.079342   19.26
# 75      1045         680          3903  ...     18167.0  -1.076189   19.86
# 76       964         512          4108  ...     11200.0  -1.084747   19.41
# 77      1210         310          3710  ...     13197.0  -1.082294   18.65
# 78      1091         150          2950  ...     12300.0  -1.083396   19.82
# 79       969         124          2516  ...     13900.0  -1.081430   20.23
# 80       995          60          2623  ...     15800.0  -1.079097   20.47
# 81      1225          70          2910  ...     11600.0  -1.084256   19.80
# 82      1090          65          2885  ...     10306.0  -1.085845   19.30
# 83      1342          34          2761  ...      9000.0  -1.087449   18.87
# 84       239         527          2327  ...      9931.0  -1.086306   18.61
# 85       643         410          2286  ...      9730.0  -1.086553   18.51
# 86       426         520          2060  ...     11763.0  -1.084055   19.66
# 87       802         507          2925  ...     12400.0  -1.083273   19.09
# 88       966         507          3120  ...     13700.0  -1.081676   19.54
# 89       444         672          3320  ...     17349.0  -1.077194   20.80
# 90      1089         450          3509  ...     13522.0  -1.081895   21.00
# 91       488         824          3620  ...     17358.0  -1.077183   20.93
# 92       855         480          3970  ...     11554.0  -1.084312   19.60
# 93       423         816          3744  ...     11267.0  -1.084665   19.20
# 94       147         820          4921  ...     15753.0  -1.079154   18.50
# 95       702         555          3754  ...     13785.0  -1.081572   19.30
# 96       775          79          3266  ...     10336.0  -1.085808   19.30
# 97       136         500          2262  ...      5245.0  -1.092062   20.36
# 98       193         400          2051  ...      8739.0  -1.087770   19.60
# 99       855          79          2341  ...      9164.0  -1.087248   18.78
# 100      192         300          1771  ...      6516.0  -1.090500   18.50
# 101      186         432          1828  ...      8376.0  -1.088216   20.20
# 102      234         582          2096  ...      9892.0  -1.086354   20.30
# 103      394         200          2908  ...     10510.0  -1.085594   19.40
# 104      159        1200          4218  ...     10776.0  -1.085268   19.30
# 105      134        1200          4409  ...     10990.0  -1.085005   19.80
# 106      264        1455          4523  ...     11200.0  -1.084747   19.50
# 107      543         820          3083  ...      9193.0  -1.087212   19.80
# 108      220        1129          5198  ...     13027.0  -1.082503   19.80
# 109      385         430          3440  ...     12136.0  -1.083597   19.60
#
#      rinde  humedad  cant_lluvia  lluvia_s  tem_max  temp_media  temp_min
# 74   60.46     57.6        208.6  0.003419     20.9        14.3       6.4
# 75   61.52     58.1        130.3 -0.458457     20.5        12.9       5.8
# 76   55.77     60.3        199.5 -0.050260     20.7        13.8       6.8
# 77   61.69     54.9         85.5 -0.722723     20.4        12.9       5.5
# 78   57.13     56.5         92.5 -0.681432     21.9        14.5       7.1
# 79   59.84     56.2         96.0 -0.660786     21.7        14.2       6.8
# 80   60.56     60.3        240.0  0.188641     20.6        13.2       5.8
# 81   54.04     62.2        335.2  0.750207     19.9        14.4       4.7
# 82   58.81     58.1        155.7 -0.308628     21.0        14.8       5.5
# 83   61.83     53.7         82.5 -0.740420     24.3        13.5       4.6
# 84   64.37     18.5        267.8  0.352628     22.0        11.9       2.6
# 85   60.43     42.6         59.8 -0.874322     22.9        13.9       5.3
# 86   56.21     56.3        278.6  0.416335     20.0        13.0       6.4
# 87   61.39     49.9        355.0  0.867003     20.7        13.5       6.7
# 88   53.18     55.1        302.4  0.556726     19.3        12.4       5.6
# 89   65.27     42.0        212.5  0.026424     23.0        14.0       5.5
# 90   61.80     21.9        188.1 -0.117506     20.5        13.3       6.1
# 91   61.65     56.4        218.0  0.058868     19.5        12.7       6.4
# 92   61.10     55.7        161.0 -0.277364     22.2        12.2       3.7
# 93   57.50     58.2        143.9 -0.378233     22.4        12.9       4.9
# 94   56.80     61.6        179.8 -0.166466     21.5        12.5       4.3
# 95   57.80     51.5        200.5 -0.044361     21.1        13.4       6.0
# 96   58.30     50.9        194.4 -0.080344     20.0        12.5       5.2
# 97   58.90     54.3        163.3 -0.263797     21.1        13.4       5.8
# 98   53.10     50.1        168.5 -0.233123     20.8        13.4       6.0
# 99   56.70     50.5        184.0 -0.141692     20.6        13.1       5.7
# 100  55.00     50.6        130.7 -0.456098     21.3        13.8       6.3
# 101  53.90     50.4        171.8 -0.213657     20.9        13.5       6.1
# 102  53.90     56.3        197.6 -0.061468     20.7        13.6       6.8
# 103  56.10     54.0        187.2 -0.122815     20.6        13.6       6.7
# 104  59.10     51.9        112.9 -0.561096     21.0        13.8       6.3
# 105  60.00     61.4        218.0  0.058868     20.8        13.5       6.4
# 106  59.30     57.5        265.2  0.337291     21.6        14.2       6.8
# 107  61.30     55.8         93.2 -0.677302     21.6        13.8       6.0
# 108  56.90     55.8        170.7 -0.220146     21.4        13.6       5.8
# 109  56.10     54.5         92.0 -0.684381     22.0        14.3       6.6
#
# [36 rows x 21 columns]

# %%
data[data.departamento=='BIEDMA']
# Out:
#         fecha  hectareas      ha_s departamento  carneros  ovejas  borregos  \
# 0  2012-12-31    1294000  0.143866       BIEDMA      5785   93378     30168
# 1  2013-12-31    1294000  0.143866       BIEDMA      5376   82998     25341
# 2  2014-12-31    1294000  0.143866       BIEDMA      4785   82706     29379
# 3  2015-12-31    1294000  0.143866       BIEDMA      4440   89262     29663
# 4  2016-12-31    1294000  0.143866       BIEDMA      4452   82295     33662
# 5  2017-12-31    1294000  0.143866       BIEDMA      4688   87179     33148
# 6  2018-12-31    1294000  0.143866       BIEDMA      4767   86473     36233
# 7  2019-12-31    1294000  0.143866       BIEDMA      4887   84400     31784
# 8  2020-12-31    1294000  0.143866       BIEDMA      3084   82806     29134
#
#    capones  cordero/as  total_ovinos  ...  kilos_lana  kg_lana_s  finura  \
# 0    48447       16071        193849  ...    649130.0  -0.301153   19.80
# 1    47350       26832        187897  ...    620176.0  -0.336719   19.60
# 2    35155       29900        181925  ...    649130.0  -0.301153   20.10
# 3    35437       32343        191145  ...    672480.0  -0.272472   18.58
# 4    33470       21326        175205  ...    653800.0  -0.295417   17.99
# 5    33947       20900        179862  ...    653800.0  -0.295417   19.73
# 6    31347       22289        181109  ...    653800.0  -0.295417   18.86
# 7    34032       23424        178527  ...    629189.1  -0.325648   18.95
# 8    33727       25394        174145  ...    630450.0  -0.324099   19.10
#
#    rinde  humedad  cant_lluvia  lluvia_s  tem_max  temp_media  temp_min
# 0  58.06     58.4         46.4 -0.953366     18.1        12.4       6.7
# 1  56.68     64.7        226.5  0.109007     19.9        14.2       8.8
# 2  61.19     60.5        331.3  0.727202     20.6        14.7       9.2
# 3  58.18     58.7        114.2 -0.553428     22.2        15.8      10.2
# 4  59.93     57.5         88.9 -0.702667     25.2        18.6      12.9
# 5  58.95     55.8        291.9  0.494789     19.1        13.6       8.4
# 6  58.89     56.3         99.0 -0.643089     21.0        14.8       9.5
# 7  57.81     54.1        295.5  0.516025     18.7        13.6       8.7
# 8  58.71     58.3        191.4 -0.098040     20.5        14.6       9.2
#
# [9 rows x 21 columns]

# %% [markdown]
# ## Prueba con dataset Mirabueno escalados

# %%
X_prediccion = data_mirabueno[["lluvia_s", "ovinos_s","ha_s"]]
y_real = data_mirabueno[['kg_lana_s']]

# %%
y_real
# Out:
#      kg_lana_s
# 74   -1.079342
# 75   -1.076189
# 76   -1.084747
# 77   -1.082294
# 78   -1.083396
# 79   -1.081430
# 80   -1.079097
# 81   -1.084256
# 82   -1.085845
# 83   -1.087449
# 84   -1.086306
# 85   -1.086553
# 86   -1.084055
# 87   -1.083273
# 88   -1.081676
# 89   -1.077194
# 90   -1.081895
# 91   -1.077183
# 92   -1.084312
# 93   -1.084665
# 94   -1.079154
# 95   -1.081572
# 96   -1.085808
# 97   -1.092062
# 98   -1.087770
# 99   -1.087248
# 100  -1.090500
# 101  -1.088216
# 102  -1.086354
# 103  -1.085594
# 104  -1.085268
# 105  -1.085005
# 106  -1.084747
# 107  -1.087212
# 108  -1.082503
# 109  -1.083597

# %%
resultado_prediccion_mirabueno_scaler = modelo_lana.predict(X_prediccion)
y_prediccion = transform_data(resultado_prediccion_mirabueno_scaler)
y_prediccion
# Out:
# /home/lucila/anaconda3/lib/python3.9/site-packages/sklearn/base.py:443: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# [-1.1117552410792355,
#  -1.0981199542762619,
#  -1.1082470428503808,
#  -1.0918255947045636,
#  -1.0962419922151334,
#  -1.0986847987542392,
#  -1.1211469943912045,
#  -1.1350574359511172,
#  -1.1065868252660216,
#  -1.0954709620546157,
#  -1.1268591901964433,
#  -1.0939204443276895,
#  -1.1297387253459803,
#  -1.1381447387819805,
#  -1.1289227960626105,
#  -1.113740383283784,
#  -1.1090343919749197,
#  -1.1133126932791422,
#  -1.1027167900707233,
#  -1.1009760779312467,
#  -1.1015783422416392,
#  -1.109944242951372,
#  -1.1110931861665636,
#  -1.1105035435840946,
#  -1.1122481736264538,
#  -1.1134560869115946,
#  -1.1074463034447453,
#  -1.1137424288251452,
#  -1.1166858451852566,
#  -1.111502195550722,
#  -1.0939810549878726,
#  -1.1098848128822065,
#  -1.1169045127293906,
#  -1.0957756129510325,
#  -1.0989260279648707,
#  -1.094033535936196]

# %%
y_real.insert(1, "y_prediccion", y_prediccion, allow_duplicates=False)
y_real
# Out:
#      kg_lana_s  y_prediccion
# 74   -1.079342     -1.111755
# 75   -1.076189     -1.098120
# 76   -1.084747     -1.108247
# 77   -1.082294     -1.091826
# 78   -1.083396     -1.096242
# 79   -1.081430     -1.098685
# 80   -1.079097     -1.121147
# 81   -1.084256     -1.135057
# 82   -1.085845     -1.106587
# 83   -1.087449     -1.095471
# 84   -1.086306     -1.126859
# 85   -1.086553     -1.093920
# 86   -1.084055     -1.129739
# 87   -1.083273     -1.138145
# 88   -1.081676     -1.128923
# 89   -1.077194     -1.113740
# 90   -1.081895     -1.109034
# 91   -1.077183     -1.113313
# 92   -1.084312     -1.102717
# 93   -1.084665     -1.100976
# 94   -1.079154     -1.101578
# 95   -1.081572     -1.109944
# 96   -1.085808     -1.111093
# 97   -1.092062     -1.110504
# 98   -1.087770     -1.112248
# 99   -1.087248     -1.113456
# 100  -1.090500     -1.107446
# 101  -1.088216     -1.113742
# 102  -1.086354     -1.116686
# 103  -1.085594     -1.111502
# 104  -1.085268     -1.093981
# 105  -1.085005     -1.109885
# 106  -1.084747     -1.116905
# 107  -1.087212     -1.095776
# 108  -1.082503     -1.098926
# 109  -1.083597     -1.094034

# %%
plt.plot(range(len(y_real)),y_real,label=["Real", "Prediccion"])
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')
plt.xlabel('muestras')
plt.ylabel('kilos lana')
plt.legend()
plt.show()

# %%
print('Exactitud de la predicción:')
print(str(round(r2_score(y_prediccion, resultado_prediccion_mirabueno_scaler),4)))
# Out:
# Exactitud de la predicción:
# -62.3169

# %%
print('MSE:')
print(str(round(mean_squared_error(y_prediccion, resultado_prediccion_mirabueno_scaler),4)))
# Out:
# MSE:
# 0.0008
